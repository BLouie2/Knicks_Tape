# %%
# %matplotlib inline
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
# !pip install twitterscraper
# Out:
# ...
#      |████████████████████████████████| 92kB 1.4MB/s eta 0:00:011
# ...
#   Stored in directory: /Users/brianlouie/Library/Caches/pip/wheels/1b/38/dc/ca97310643483cd772d3dee2b18ce210fbca0b8e6ca01595a5
# ...
#   Stored in directory: /Users/brianlouie/Library/Caches/pip/wheels/a0/b0/b2/4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# Successfully built twitterscraper bs4
# ...
# WARNING: You are using pip version 19.1.1, however version 19.2.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip install --upgrade pip
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/8d/07/f7d7ced2f97ca3098c16565efbe6b15fafcba53e8d9bdb431e09140514b0/pip-19.2.2-py2.py3-none-any.whl
# ...
#   Found existing installation: pip 19.1.1
#     Uninstalling pip-19.1.1:
#       Successfully uninstalled pip-19.1.1
# ...

# %%
# !pip install langdetect
from langdetect import detect
# Out:
# ...
#      |████████████████████████████████| 1.0MB 2.6MB/s eta 0:00:01
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.7-cp36-none-any.whl size=992306 sha256=292d370c3804af5b813da157b09ac51642810baf858f14a016d11298cd583030
#   Stored in directory: /Users/brianlouie/Library/Caches/pip/wheels/ec/0c/a9/1647275e7ef5014e7b83ff30105180e332867d65e7617ddafe
# Successfully built langdetect
# ...

# %%
# !pip install vaderSentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()
# Out:
# ...
#      |████████████████████████████████| 133kB 2.6MB/s eta 0:00:01
# ...

# %%
begin_date = dt.datetime.strptime("Jul 31 2019", "%b %d %Y").date()

# %%
from twitterscraper import query_tweets

tweets = query_tweets("Carmelo Anthony OR Me7o", begindate=begin_date)
# Out:
# INFO: queries: ['Carmelo Anthony OR Me7o since:2019-07-31 until:2019-08-01', 'Carmelo Anthony OR Me7o since:2019-08-01 until:2019-08-02', 'Carmelo Anthony OR Me7o since:2019-08-02 until:2019-08-03', 'Carmelo Anthony OR Me7o since:2019-08-03 until:2019-08-04', 'Carmelo Anthony OR Me7o since:2019-08-04 until:2019-08-05', 'Carmelo Anthony OR Me7o since:2019-08-05 until:2019-08-06', 'Carmelo Anthony OR Me7o since:2019-08-06 until:2019-08-07', 'Carmelo Anthony OR Me7o since:2019-08-07 until:2019-08-08', 'Carmelo Anthony OR Me7o since:2019-08-08 until:2019-08-09', 'Carmelo Anthony OR Me7o since:2019-08-09 until:2019-08-10', 'Carmelo Anthony OR Me7o since:2019-08-10 until:2019-08-11', 'Carmelo Anthony OR Me7o since:2019-08-11 until:2019-08-12', 'Carmelo Anthony OR Me7o since:2019-08-12 until:2019-08-13', 'Carmelo Anthony OR Me7o since:2019-08-13 until:2019-08-14']
# INFO: Querying Carmelo Anthony OR Me7o since:2019-08-01 until:2019-08-02
# ...

# %%
print(len(tweets))
# Out:
# 9282

# %%
tweets[10].__dict__
# Out:
# {'username': 'elbernabeucom',
#  'fullname': 'El Bernabéu',
#  'user_id': '744673274',
#  'tweet_id': '1160324461922381824',
#  'tweet_url': '/elbernabeucom/status/1160324461922381824',
#  'timestamp': datetime.datetime(2019, 8, 10, 22, 58, 4),
#  'timestamp_epochs': 1565477884,
#  'replies': 0,
#  'retweets': 9,
#  'likes': 34,
#  'is_retweet': 0,
#  'retweeter_username': '',
#  'retweeter_userid': '',
#  'retweet_id': '',
#  'text': 'Carmelo Anthony: "Lo que sé del Atlético es que se siente el primo pequeño del Madrid" http://ww.elbernabeu.com/RB1tsv\xa0',
# ...

# %%
tweet_list = (t.__dict__ for t in tweets)
df = pd.DataFrame(tweet_list)

df.head(7)
# Out:
#                       fullname  \
# 0                        Riley
# 1                           M.
# 2  NOLA Legend Carmelo Anthony
# 3                 Rigo Herrera
# 4                   Trelephant
# 5                Duke for life
# 6  NOLA Legend Carmelo Anthony
#
#                                                 html  is_retweet  likes  \
# 0  <p class="TweetTextSize js-tweet-text tweet-te...           0      6
# 1  <p class="TweetTextSize js-tweet-text tweet-te...           0      3
# 2  <p class="TweetTextSize js-tweet-text tweet-te...           0      2
# 3  <p class="TweetTextSize js-tweet-text tweet-te...           0      5
# 4  <p class="TweetTextSize js-tweet-text tweet-te...           0      1
# 5  <p class="TweetTextSize js-tweet-text tweet-te...           0      1
# 6  <p class="TweetTextSize js-tweet-text tweet-te...           0     96
#
#    replies retweet_id retweeter_userid retweeter_username  retweets  \
# ...

# %%
#df['lang'] = df['text'].map(lambda x: detect(x))
#df = df[df['lang'] == 'en']

text_test = tweets[10].text
detect(text= text_test)
# Out:
# 'es'

# %%
detect(text = df['text'][11])
# Out:
# 'en'

# %%
list(map(lambda x: x**2,[1, 2, 3, 4]))
# Out:
# [1, 4, 9, 16]

# %%
#df['lang'] = map(lambda x: detect(x), df['text'])
#didn't work only created an object not detected language of text

# %%
df = df.drop(columns='lang', axis = 0)

# %%
df['text'].map(lambda x: detect(x), df['text'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-104-e8f3c5347651> in <module>()
# ----> 1 df['text'].map(lambda x: detect(x), df['text'])
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    2994         """
#    2995         new_values = super(Series, self)._map_values(
# -> 2996             arg, na_action=na_action)
#    2997         return self._constructor(new_values,
#    2998                                  index=self.index).__finalize__(self)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#     994             values = self.astype(object)
#     995             values = getattr(values, 'values', values)
# --> 996             if na_action == 'ignore':
#     997                 def map_f(values, f):
# ...
